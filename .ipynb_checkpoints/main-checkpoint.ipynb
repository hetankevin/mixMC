# %%
from experiments import *
papply_settings["parallel"] = False
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Experiments on Synthetic Data

# %% [markdown]
# ## Varying the Trail Length

# %%
setup_end2end_tlen = {
    'n': [10],
    'L': [5],
    'tau': [0.1],
    't_len': np.linspace(100, 500, 19, dtype=int),
    'seed': range(5),
}

plot_end2end_tlen(setup_end2end_tlen, n_observations=2500)


setup_end2end_tlen = {
    'n': [10],
    'L': [5],
    'tau': [0.1],
    't_len': np.linspace(100, 5000, 19, dtype=int),
    'seed': range(5),
}

plot_end2end_tlen(setup_end2end_tlen, n_observations=25000)
# Out:
# test_baseline(10, 5, 0.1, 144, 17, seed=2) >> cache/test_baseline-10--5--0.1--144--17--seed-2.pkl
# test_methods(10, 5, 0.1, 144, 17, seed=3) >> cache/test_methods-10--5--0.1--144--17--seed-3.pkl
# gen_example(10, 5, 0.1, 144, 17, f=None, seed=3) >> cache/gen_example-10--5--0.1--144--17--f-None--seed-3.pkl
# test_baseline(10, 5, 0.1, 144, 17, seed=3) >> cache/test_baseline-10--5--0.1--144--17--seed-3.pkl
# gen_example(10, 5, 0.1, 145, 17, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.1--145--17--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.1, 144, 17, seed=4) >> cache/test_methods-10--5--0.1--144--17--seed-4.pkl
# gen_example(10, 5, 0.1, 144, 17, f=None, seed=4) >> cache/gen_example-10--5--0.1--144--17--f-None--seed-4.pkl
# test_baseline(10, 5, 0.1, 144, 17, seed=4) >> cache/test_baseline-10--5--0.1--144--17--seed-4.pkl
# gen_example(10, 5, 0.1, 145, 17, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.1--145--17--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.1, 166, 15, seed=0) >> cache/test_methods-10--5--0.1--166--15--seed-0.pkl
# gen_example(10, 5, 0.1, 166, 15, f=None, seed=0) >> cache/gen_example-10--5--0.1--166--15--f-None--seed-0.pkl
# test_baseline(10, 5, 0.1, 166, 15, seed=0) >> cache/test_baseline-10--5--0.1--166--15--seed-0.pkl
# gen_example(10, 5, 0.1, 167, 15, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.1--167--15--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.1, 166, 15, seed=1) >> cache/test_methods-10--5--0.1--166--15--seed-1.pkl
# gen_example(10, 5, 0.1, 166, 15, f=None, seed=1) >> cache/gen_example-10--5--0.1--166--15--f-None--seed-1.pkl
# test_baseline(10, 5, 0.1, 166, 15, seed=1) >> cache/test_baseline-10--5--0.1--166--15--seed-1.pkl
# gen_example(10, 5, 0.1, 167, 15, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.1--167--15--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.1, 166, 15, seed=2) >> cache/test_methods-10--5--0.1--166--15--seed-2.pkl
# gen_example(10, 5, 0.1, 166, 15, f=None, seed=2) >> cache/gen_example-10--5--0.1--166--15--f-None--seed-2.pkl
# test_baseline(10, 5, 0.1, 166, 15, seed=2) >> cache/test_baseline-10--5--0.1--166--15--seed-2.pkl
# gen_example(10, 5, 0.1, 167, 15, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.1--167--15--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.1, 166, 15, seed=3) >> cache/test_methods-10--5--0.1--166--15--seed-3.pkl
# gen_example(10, 5, 0.1, 166, 15, f=None, seed=3) >> cache/gen_example-10--5--0.1--166--15--f-None--seed-3.pkl
# test_baseline(10, 5, 0.1, 166, 15, seed=3) >> cache/test_baseline-10--5--0.1--166--15--seed-3.pkl
# gen_example(10, 5, 0.1, 167, 15, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.1--167--15--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.1, 166, 15, seed=4) >> cache/test_methods-10--5--0.1--166--15--seed-4.pkl
# gen_example(10, 5, 0.1, 166, 15, f=None, seed=4) >> cache/gen_example-10--5--0.1--166--15--f-None--seed-4.pkl
# test_baseline(10, 5, 0.1, 166, 15, seed=4) >> cache/test_baseline-10--5--0.1--166--15--seed-4.pkl
# gen_example(10, 5, 0.1, 167, 15, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.1--167--15--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.1, 188, 13, seed=0) >> cache/test_methods-10--5--0.1--188--13--seed-0.pkl
# gen_example(10, 5, 0.1, 188, 13, f=None, seed=0) >> cache/gen_example-10--5--0.1--188--13--f-None--seed-0.pkl
# test_baseline(10, 5, 0.1, 188, 13, seed=0) >> cache/test_baseline-10--5--0.1--188--13--seed-0.pkl
# gen_example(10, 5, 0.1, 189, 13, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.1--189--13--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.1, 188, 13, seed=1) >> cache/test_methods-10--5--0.1--188--13--seed-1.pkl
# gen_example(10, 5, 0.1, 188, 13, f=None, seed=1) >> cache/gen_example-10--5--0.1--188--13--f-None--seed-1.pkl
# test_baseline(10, 5, 0.1, 188, 13, seed=1) >> cache/test_baseline-10--5--0.1--188--13--seed-1.pkl
# gen_example(10, 5, 0.1, 189, 13, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.1--189--13--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.1, 188, 13, seed=2) >> cache/test_methods-10--5--0.1--188--13--seed-2.pkl
# gen_example(10, 5, 0.1, 188, 13, f=None, seed=2) >> cache/gen_example-10--5--0.1--188--13--f-None--seed-2.pkl
# test_baseline(10, 5, 0.1, 188, 13, seed=2) >> cache/test_baseline-10--5--0.1--188--13--seed-2.pkl
# gen_example(10, 5, 0.1, 189, 13, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.1--189--13--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.1, 188, 13, seed=3) >> cache/test_methods-10--5--0.1--188--13--seed-3.pkl
# gen_example(10, 5, 0.1, 188, 13, f=None, seed=3) >> cache/gen_example-10--5--0.1--188--13--f-None--seed-3.pkl
# test_baseline(10, 5, 0.1, 188, 13, seed=3) >> cache/test_baseline-10--5--0.1--188--13--seed-3.pkl
# gen_example(10, 5, 0.1, 189, 13, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.1--189--13--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.1, 188, 13, seed=4) >> cache/test_methods-10--5--0.1--188--13--seed-4.pkl
# gen_example(10, 5, 0.1, 188, 13, f=None, seed=4) >> cache/gen_example-10--5--0.1--188--13--f-None--seed-4.pkl
# test_baseline(10, 5, 0.1, 188, 13, seed=4) >> cache/test_baseline-10--5--0.1--188--13--seed-4.pkl
# gen_example(10, 5, 0.1, 189, 13, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.1--189--13--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.1, 211, 11, seed=0) >> cache/test_methods-10--5--0.1--211--11--seed-0.pkl
# gen_example(10, 5, 0.1, 211, 11, f=None, seed=0) >> cache/gen_example-10--5--0.1--211--11--f-None--seed-0.pkl
# test_baseline(10, 5, 0.1, 211, 11, seed=0) >> cache/test_baseline-10--5--0.1--211--11--seed-0.pkl
# gen_example(10, 5, 0.1, 212, 11, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.1--212--11--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.1, 211, 11, seed=1) >> cache/test_methods-10--5--0.1--211--11--seed-1.pkl
# gen_example(10, 5, 0.1, 211, 11, f=None, seed=1) >> cache/gen_example-10--5--0.1--211--11--f-None--seed-1.pkl

# %%
setup_end2end_tlen = {
    'n': [10],
    'L': [5],
    'tau': [0.1],
    't_len': np.linspace(100, 500, 19, dtype=int),
    'seed': range(5),
}

plot_end2end_tlen(setup_end2end_tlen, n_observations=2500)


setup_end2end_tlen = {
    'n': [10],
    'L': [5],
    'tau': [0.1],
    't_len': np.linspace(100, 5000, 19, dtype=int),
    'seed': range(5),
}

plot_end2end_tlen(setup_end2end_tlen, n_observations=25000)

# %% [markdown]
# ## Varying the Discretization Rate

# %%
setup_end2end_tau = {
    'n': [10],
    'L': [5],
    'tau': np.linspace(0.01, 2.0, 20),
    't_len': [25],
    'n_samples': [50],
    'seed': range(5),
}

plot_end2end_tau(setup_end2end_tau)


setup_end2end_tau = {
    'n': [10],
    'L': [5],
    'tau': np.linspace(0.01, 2.0, 20),
    't_len': [500],
    'n_samples': [50],
    'seed': range(5),
}

plot_end2end_tau(setup_end2end_tau)
# Out:
# test_methods(10, 5, 0.01, 25, 50, seed=0) >> cache/test_methods-10--5--0.01--25--50--seed-0.pkl
# test_baseline(10, 5, 0.01, 25, 50, seed=1) >> cache/test_baseline-10--5--0.01--25--50--seed-1.pkl
# gen_example(10, 5, 0.01, 26, 50, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.01--26--50--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.01, 25, 50, seed=1) >> cache/test_methods-10--5--0.01--25--50--seed-1.pkl
# gen_example(10, 5, 0.01, 25, 50, f=None, seed=1) >> cache/gen_example-10--5--0.01--25--50--f-None--seed-1.pkl
# test_baseline(10, 5, 0.01, 25, 50, seed=2) >> cache/test_baseline-10--5--0.01--25--50--seed-2.pkl
# gen_example(10, 5, 0.01, 26, 50, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.01--26--50--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.01, 25, 50, seed=2) >> cache/test_methods-10--5--0.01--25--50--seed-2.pkl
# gen_example(10, 5, 0.01, 25, 50, f=None, seed=2) >> cache/gen_example-10--5--0.01--25--50--f-None--seed-2.pkl
# test_baseline(10, 5, 0.01, 25, 50, seed=3) >> cache/test_baseline-10--5--0.01--25--50--seed-3.pkl
# gen_example(10, 5, 0.01, 26, 50, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.01--26--50--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.01, 25, 50, seed=3) >> cache/test_methods-10--5--0.01--25--50--seed-3.pkl
# gen_example(10, 5, 0.01, 25, 50, f=None, seed=3) >> cache/gen_example-10--5--0.01--25--50--f-None--seed-3.pkl
# test_baseline(10, 5, 0.01, 25, 50, seed=4) >> cache/test_baseline-10--5--0.01--25--50--seed-4.pkl
# gen_example(10, 5, 0.01, 26, 50, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.01--26--50--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.01, 25, 50, seed=4) >> cache/test_methods-10--5--0.01--25--50--seed-4.pkl
# gen_example(10, 5, 0.01, 25, 50, f=None, seed=4) >> cache/gen_example-10--5--0.01--25--50--f-None--seed-4.pkl
# test_baseline(10, 5, 0.11473684210526315, 25, 50, seed=0) >> cache/test_baseline-10--5--0.11473684210526315--25--50--seed-0.pkl
# gen_example(10, 5, 0.11473684210526315, 26, 50, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.11473684210526315--26--50--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.11473684210526315, 25, 50, seed=0) >> cache/test_methods-10--5--0.11473684210526315--25--50--seed-0.pkl
# gen_example(10, 5, 0.11473684210526315, 25, 50, f=None, seed=0) >> cache/gen_example-10--5--0.11473684210526315--25--50--f-None--seed-0.pkl
# test_baseline(10, 5, 0.11473684210526315, 25, 50, seed=1) >> cache/test_baseline-10--5--0.11473684210526315--25--50--seed-1.pkl
# gen_example(10, 5, 0.11473684210526315, 26, 50, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.11473684210526315--26--50--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.11473684210526315, 25, 50, seed=1) >> cache/test_methods-10--5--0.11473684210526315--25--50--seed-1.pkl
# gen_example(10, 5, 0.11473684210526315, 25, 50, f=None, seed=1) >> cache/gen_example-10--5--0.11473684210526315--25--50--f-None--seed-1.pkl
# test_baseline(10, 5, 0.11473684210526315, 25, 50, seed=2) >> cache/test_baseline-10--5--0.11473684210526315--25--50--seed-2.pkl
# gen_example(10, 5, 0.11473684210526315, 26, 50, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.11473684210526315--26--50--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.11473684210526315, 25, 50, seed=2) >> cache/test_methods-10--5--0.11473684210526315--25--50--seed-2.pkl
# gen_example(10, 5, 0.11473684210526315, 25, 50, f=None, seed=2) >> cache/gen_example-10--5--0.11473684210526315--25--50--f-None--seed-2.pkl
# test_baseline(10, 5, 0.11473684210526315, 25, 50, seed=3) >> cache/test_baseline-10--5--0.11473684210526315--25--50--seed-3.pkl
# gen_example(10, 5, 0.11473684210526315, 26, 50, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.11473684210526315--26--50--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.11473684210526315, 25, 50, seed=3) >> cache/test_methods-10--5--0.11473684210526315--25--50--seed-3.pkl
# gen_example(10, 5, 0.11473684210526315, 25, 50, f=None, seed=3) >> cache/gen_example-10--5--0.11473684210526315--25--50--f-None--seed-3.pkl
# test_baseline(10, 5, 0.11473684210526315, 25, 50, seed=4) >> cache/test_baseline-10--5--0.11473684210526315--25--50--seed-4.pkl
# gen_example(10, 5, 0.11473684210526315, 26, 50, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.11473684210526315--26--50--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.11473684210526315, 25, 50, seed=4) >> cache/test_methods-10--5--0.11473684210526315--25--50--seed-4.pkl
# gen_example(10, 5, 0.11473684210526315, 25, 50, f=None, seed=4) >> cache/gen_example-10--5--0.11473684210526315--25--50--f-None--seed-4.pkl
# test_baseline(10, 5, 0.21947368421052632, 25, 50, seed=0) >> cache/test_baseline-10--5--0.21947368421052632--25--50--seed-0.pkl
# gen_example(10, 5, 0.21947368421052632, 26, 50, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.21947368421052632--26--50--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.21947368421052632, 25, 50, seed=0) >> cache/test_methods-10--5--0.21947368421052632--25--50--seed-0.pkl
# gen_example(10, 5, 0.21947368421052632, 25, 50, f=None, seed=0) >> cache/gen_example-10--5--0.21947368421052632--25--50--f-None--seed-0.pkl
# test_baseline(10, 5, 0.21947368421052632, 25, 50, seed=1) >> cache/test_baseline-10--5--0.21947368421052632--25--50--seed-1.pkl
# gen_example(10, 5, 0.21947368421052632, 26, 50, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.21947368421052632--26--50--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.21947368421052632, 25, 50, seed=1) >> cache/test_methods-10--5--0.21947368421052632--25--50--seed-1.pkl
# gen_example(10, 5, 0.21947368421052632, 25, 50, f=None, seed=1) >> cache/gen_example-10--5--0.21947368421052632--25--50--f-None--seed-1.pkl
# test_baseline(10, 5, 0.21947368421052632, 25, 50, seed=2) >> cache/test_baseline-10--5--0.21947368421052632--25--50--seed-2.pkl
# gen_example(10, 5, 0.21947368421052632, 26, 50, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.21947368421052632--26--50--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.21947368421052632, 25, 50, seed=2) >> cache/test_methods-10--5--0.21947368421052632--25--50--seed-2.pkl
# gen_example(10, 5, 0.21947368421052632, 25, 50, f=None, seed=2) >> cache/gen_example-10--5--0.21947368421052632--25--50--f-None--seed-2.pkl
# test_baseline(10, 5, 0.21947368421052632, 25, 50, seed=3) >> cache/test_baseline-10--5--0.21947368421052632--25--50--seed-3.pkl
# gen_example(10, 5, 0.21947368421052632, 26, 50, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.21947368421052632--26--50--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.21947368421052632, 25, 50, seed=3) >> cache/test_methods-10--5--0.21947368421052632--25--50--seed-3.pkl
# gen_example(10, 5, 0.21947368421052632, 25, 50, f=None, seed=3) >> cache/gen_example-10--5--0.21947368421052632--25--50--f-None--seed-3.pkl
# test_baseline(10, 5, 0.21947368421052632, 25, 50, seed=4) >> cache/test_baseline-10--5--0.21947368421052632--25--50--seed-4.pkl
# gen_example(10, 5, 0.21947368421052632, 26, 50, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.21947368421052632--26--50--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.21947368421052632, 25, 50, seed=4) >> cache/test_methods-10--5--0.21947368421052632--25--50--seed-4.pkl
# gen_example(10, 5, 0.21947368421052632, 25, 50, f=None, seed=4) >> cache/gen_example-10--5--0.21947368421052632--25--50--f-None--seed-4.pkl
# test_baseline(10, 5, 0.3242105263157895, 25, 50, seed=0) >> cache/test_baseline-10--5--0.3242105263157895--25--50--seed-0.pkl
# gen_example(10, 5, 0.3242105263157895, 26, 50, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.3242105263157895--26--50--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.3242105263157895, 25, 50, seed=0) >> cache/test_methods-10--5--0.3242105263157895--25--50--seed-0.pkl
# gen_example(10, 5, 0.3242105263157895, 25, 50, f=None, seed=0) >> cache/gen_example-10--5--0.3242105263157895--25--50--f-None--seed-0.pkl
# test_baseline(10, 5, 0.3242105263157895, 25, 50, seed=1) >> cache/test_baseline-10--5--0.3242105263157895--25--50--seed-1.pkl
# gen_example(10, 5, 0.3242105263157895, 26, 50, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.3242105263157895--26--50--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.3242105263157895, 25, 50, seed=1) >> cache/test_methods-10--5--0.3242105263157895--25--50--seed-1.pkl
# gen_example(10, 5, 0.3242105263157895, 25, 50, f=None, seed=1) >> cache/gen_example-10--5--0.3242105263157895--25--50--f-None--seed-1.pkl
# test_baseline(10, 5, 0.3242105263157895, 25, 50, seed=2) >> cache/test_baseline-10--5--0.3242105263157895--25--50--seed-2.pkl
# gen_example(10, 5, 0.3242105263157895, 26, 50, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.3242105263157895--26--50--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.3242105263157895, 25, 50, seed=2) >> cache/test_methods-10--5--0.3242105263157895--25--50--seed-2.pkl
# gen_example(10, 5, 0.3242105263157895, 25, 50, f=None, seed=2) >> cache/gen_example-10--5--0.3242105263157895--25--50--f-None--seed-2.pkl
# test_baseline(10, 5, 0.3242105263157895, 25, 50, seed=3) >> cache/test_baseline-10--5--0.3242105263157895--25--50--seed-3.pkl
# gen_example(10, 5, 0.3242105263157895, 26, 50, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.3242105263157895--26--50--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.3242105263157895, 25, 50, seed=3) >> cache/test_methods-10--5--0.3242105263157895--25--50--seed-3.pkl
# gen_example(10, 5, 0.3242105263157895, 25, 50, f=None, seed=3) >> cache/gen_example-10--5--0.3242105263157895--25--50--f-None--seed-3.pkl
# test_baseline(10, 5, 0.3242105263157895, 25, 50, seed=4) >> cache/test_baseline-10--5--0.3242105263157895--25--50--seed-4.pkl
# gen_example(10, 5, 0.3242105263157895, 26, 50, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.3242105263157895--26--50--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.3242105263157895, 25, 50, seed=4) >> cache/test_methods-10--5--0.3242105263157895--25--50--seed-4.pkl
# gen_example(10, 5, 0.3242105263157895, 25, 50, f=None, seed=4) >> cache/gen_example-10--5--0.3242105263157895--25--50--f-None--seed-4.pkl
# test_baseline(10, 5, 0.42894736842105263, 25, 50, seed=0) >> cache/test_baseline-10--5--0.42894736842105263--25--50--seed-0.pkl
# gen_example(10, 5, 0.42894736842105263, 26, 50, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.42894736842105263--26--50--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.42894736842105263, 25, 50, seed=0) >> cache/test_methods-10--5--0.42894736842105263--25--50--seed-0.pkl
# gen_example(10, 5, 0.42894736842105263, 25, 50, f=None, seed=0) >> cache/gen_example-10--5--0.42894736842105263--25--50--f-None--seed-0.pkl
# test_baseline(10, 5, 0.42894736842105263, 25, 50, seed=1) >> cache/test_baseline-10--5--0.42894736842105263--25--50--seed-1.pkl
# gen_example(10, 5, 0.42894736842105263, 26, 50, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.42894736842105263--26--50--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.42894736842105263, 25, 50, seed=1) >> cache/test_methods-10--5--0.42894736842105263--25--50--seed-1.pkl
# gen_example(10, 5, 0.42894736842105263, 25, 50, f=None, seed=1) >> cache/gen_example-10--5--0.42894736842105263--25--50--f-None--seed-1.pkl
# test_baseline(10, 5, 0.42894736842105263, 25, 50, seed=2) >> cache/test_baseline-10--5--0.42894736842105263--25--50--seed-2.pkl
# gen_example(10, 5, 0.42894736842105263, 26, 50, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.42894736842105263--26--50--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.42894736842105263, 25, 50, seed=2) >> cache/test_methods-10--5--0.42894736842105263--25--50--seed-2.pkl
# gen_example(10, 5, 0.42894736842105263, 25, 50, f=None, seed=2) >> cache/gen_example-10--5--0.42894736842105263--25--50--f-None--seed-2.pkl
# test_baseline(10, 5, 0.42894736842105263, 25, 50, seed=3) >> cache/test_baseline-10--5--0.42894736842105263--25--50--seed-3.pkl
# gen_example(10, 5, 0.42894736842105263, 26, 50, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.42894736842105263--26--50--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.42894736842105263, 25, 50, seed=3) >> cache/test_methods-10--5--0.42894736842105263--25--50--seed-3.pkl
# gen_example(10, 5, 0.42894736842105263, 25, 50, f=None, seed=3) >> cache/gen_example-10--5--0.42894736842105263--25--50--f-None--seed-3.pkl
# test_baseline(10, 5, 0.42894736842105263, 25, 50, seed=4) >> cache/test_baseline-10--5--0.42894736842105263--25--50--seed-4.pkl
# gen_example(10, 5, 0.42894736842105263, 26, 50, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.42894736842105263--26--50--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.42894736842105263, 25, 50, seed=4) >> cache/test_methods-10--5--0.42894736842105263--25--50--seed-4.pkl
# gen_example(10, 5, 0.42894736842105263, 25, 50, f=None, seed=4) >> cache/gen_example-10--5--0.42894736842105263--25--50--f-None--seed-4.pkl
# test_baseline(10, 5, 0.5336842105263158, 25, 50, seed=0) >> cache/test_baseline-10--5--0.5336842105263158--25--50--seed-0.pkl
# gen_example(10, 5, 0.5336842105263158, 26, 50, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.5336842105263158--26--50--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.5336842105263158, 25, 50, seed=0) >> cache/test_methods-10--5--0.5336842105263158--25--50--seed-0.pkl
# gen_example(10, 5, 0.5336842105263158, 25, 50, f=None, seed=0) >> cache/gen_example-10--5--0.5336842105263158--25--50--f-None--seed-0.pkl
# test_baseline(10, 5, 0.5336842105263158, 25, 50, seed=1) >> cache/test_baseline-10--5--0.5336842105263158--25--50--seed-1.pkl
# gen_example(10, 5, 0.5336842105263158, 26, 50, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.5336842105263158--26--50--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.5336842105263158, 25, 50, seed=1) >> cache/test_methods-10--5--0.5336842105263158--25--50--seed-1.pkl
# gen_example(10, 5, 0.5336842105263158, 25, 50, f=None, seed=1) >> cache/gen_example-10--5--0.5336842105263158--25--50--f-None--seed-1.pkl
# test_baseline(10, 5, 0.5336842105263158, 25, 50, seed=2) >> cache/test_baseline-10--5--0.5336842105263158--25--50--seed-2.pkl
# gen_example(10, 5, 0.5336842105263158, 26, 50, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.5336842105263158--26--50--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.5336842105263158, 25, 50, seed=2) >> cache/test_methods-10--5--0.5336842105263158--25--50--seed-2.pkl
# gen_example(10, 5, 0.5336842105263158, 25, 50, f=None, seed=2) >> cache/gen_example-10--5--0.5336842105263158--25--50--f-None--seed-2.pkl
# test_baseline(10, 5, 0.5336842105263158, 25, 50, seed=3) >> cache/test_baseline-10--5--0.5336842105263158--25--50--seed-3.pkl
# gen_example(10, 5, 0.5336842105263158, 26, 50, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.5336842105263158--26--50--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.5336842105263158, 25, 50, seed=3) >> cache/test_methods-10--5--0.5336842105263158--25--50--seed-3.pkl
# gen_example(10, 5, 0.5336842105263158, 25, 50, f=None, seed=3) >> cache/gen_example-10--5--0.5336842105263158--25--50--f-None--seed-3.pkl
# test_baseline(10, 5, 0.5336842105263158, 25, 50, seed=4) >> cache/test_baseline-10--5--0.5336842105263158--25--50--seed-4.pkl
# gen_example(10, 5, 0.5336842105263158, 26, 50, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.5336842105263158--26--50--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.5336842105263158, 25, 50, seed=4) >> cache/test_methods-10--5--0.5336842105263158--25--50--seed-4.pkl
# gen_example(10, 5, 0.5336842105263158, 25, 50, f=None, seed=4) >> cache/gen_example-10--5--0.5336842105263158--25--50--f-None--seed-4.pkl
# test_baseline(10, 5, 0.638421052631579, 25, 50, seed=0) >> cache/test_baseline-10--5--0.638421052631579--25--50--seed-0.pkl
# gen_example(10, 5, 0.638421052631579, 26, 50, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.638421052631579--26--50--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.638421052631579, 25, 50, seed=0) >> cache/test_methods-10--5--0.638421052631579--25--50--seed-0.pkl
# gen_example(10, 5, 0.638421052631579, 25, 50, f=None, seed=0) >> cache/gen_example-10--5--0.638421052631579--25--50--f-None--seed-0.pkl
# test_baseline(10, 5, 0.638421052631579, 25, 50, seed=1) >> cache/test_baseline-10--5--0.638421052631579--25--50--seed-1.pkl
# gen_example(10, 5, 0.638421052631579, 26, 50, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.638421052631579--26--50--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.638421052631579, 25, 50, seed=1) >> cache/test_methods-10--5--0.638421052631579--25--50--seed-1.pkl
# gen_example(10, 5, 0.638421052631579, 25, 50, f=None, seed=1) >> cache/gen_example-10--5--0.638421052631579--25--50--f-None--seed-1.pkl
# test_baseline(10, 5, 0.638421052631579, 25, 50, seed=2) >> cache/test_baseline-10--5--0.638421052631579--25--50--seed-2.pkl
# gen_example(10, 5, 0.638421052631579, 26, 50, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.638421052631579--26--50--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.638421052631579, 25, 50, seed=2) >> cache/test_methods-10--5--0.638421052631579--25--50--seed-2.pkl
# gen_example(10, 5, 0.638421052631579, 25, 50, f=None, seed=2) >> cache/gen_example-10--5--0.638421052631579--25--50--f-None--seed-2.pkl
# test_baseline(10, 5, 0.638421052631579, 25, 50, seed=3) >> cache/test_baseline-10--5--0.638421052631579--25--50--seed-3.pkl
# gen_example(10, 5, 0.638421052631579, 26, 50, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.638421052631579--26--50--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.638421052631579, 25, 50, seed=3) >> cache/test_methods-10--5--0.638421052631579--25--50--seed-3.pkl
# gen_example(10, 5, 0.638421052631579, 25, 50, f=None, seed=3) >> cache/gen_example-10--5--0.638421052631579--25--50--f-None--seed-3.pkl
# test_baseline(10, 5, 0.638421052631579, 25, 50, seed=4) >> cache/test_baseline-10--5--0.638421052631579--25--50--seed-4.pkl
# gen_example(10, 5, 0.638421052631579, 26, 50, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.638421052631579--26--50--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.638421052631579, 25, 50, seed=4) >> cache/test_methods-10--5--0.638421052631579--25--50--seed-4.pkl
# gen_example(10, 5, 0.638421052631579, 25, 50, f=None, seed=4) >> cache/gen_example-10--5--0.638421052631579--25--50--f-None--seed-4.pkl
# test_baseline(10, 5, 0.7431578947368421, 25, 50, seed=0) >> cache/test_baseline-10--5--0.7431578947368421--25--50--seed-0.pkl
# gen_example(10, 5, 0.7431578947368421, 26, 50, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.7431578947368421--26--50--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.7431578947368421, 25, 50, seed=0) >> cache/test_methods-10--5--0.7431578947368421--25--50--seed-0.pkl
# gen_example(10, 5, 0.7431578947368421, 25, 50, f=None, seed=0) >> cache/gen_example-10--5--0.7431578947368421--25--50--f-None--seed-0.pkl
# test_baseline(10, 5, 0.7431578947368421, 25, 50, seed=1) >> cache/test_baseline-10--5--0.7431578947368421--25--50--seed-1.pkl
# gen_example(10, 5, 0.7431578947368421, 26, 50, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.7431578947368421--26--50--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.7431578947368421, 25, 50, seed=1) >> cache/test_methods-10--5--0.7431578947368421--25--50--seed-1.pkl
# gen_example(10, 5, 0.7431578947368421, 25, 50, f=None, seed=1) >> cache/gen_example-10--5--0.7431578947368421--25--50--f-None--seed-1.pkl
# test_baseline(10, 5, 0.7431578947368421, 25, 50, seed=2) >> cache/test_baseline-10--5--0.7431578947368421--25--50--seed-2.pkl
# gen_example(10, 5, 0.7431578947368421, 26, 50, f=None, jumble=None, seed=2) >> cache/gen_example-10--5--0.7431578947368421--26--50--f-None--jumble-None--seed-2.pkl
# test_methods(10, 5, 0.7431578947368421, 25, 50, seed=2) >> cache/test_methods-10--5--0.7431578947368421--25--50--seed-2.pkl
# gen_example(10, 5, 0.7431578947368421, 25, 50, f=None, seed=2) >> cache/gen_example-10--5--0.7431578947368421--25--50--f-None--seed-2.pkl
# test_baseline(10, 5, 0.7431578947368421, 25, 50, seed=3) >> cache/test_baseline-10--5--0.7431578947368421--25--50--seed-3.pkl
# gen_example(10, 5, 0.7431578947368421, 26, 50, f=None, jumble=None, seed=3) >> cache/gen_example-10--5--0.7431578947368421--26--50--f-None--jumble-None--seed-3.pkl
# test_methods(10, 5, 0.7431578947368421, 25, 50, seed=3) >> cache/test_methods-10--5--0.7431578947368421--25--50--seed-3.pkl
# gen_example(10, 5, 0.7431578947368421, 25, 50, f=None, seed=3) >> cache/gen_example-10--5--0.7431578947368421--25--50--f-None--seed-3.pkl
# test_baseline(10, 5, 0.7431578947368421, 25, 50, seed=4) >> cache/test_baseline-10--5--0.7431578947368421--25--50--seed-4.pkl
# gen_example(10, 5, 0.7431578947368421, 26, 50, f=None, jumble=None, seed=4) >> cache/gen_example-10--5--0.7431578947368421--26--50--f-None--jumble-None--seed-4.pkl
# test_methods(10, 5, 0.7431578947368421, 25, 50, seed=4) >> cache/test_methods-10--5--0.7431578947368421--25--50--seed-4.pkl
# gen_example(10, 5, 0.7431578947368421, 25, 50, f=None, seed=4) >> cache/gen_example-10--5--0.7431578947368421--25--50--f-None--seed-4.pkl
# test_baseline(10, 5, 0.8478947368421053, 25, 50, seed=0) >> cache/test_baseline-10--5--0.8478947368421053--25--50--seed-0.pkl
# gen_example(10, 5, 0.8478947368421053, 26, 50, f=None, jumble=None, seed=0) >> cache/gen_example-10--5--0.8478947368421053--26--50--f-None--jumble-None--seed-0.pkl
# test_methods(10, 5, 0.8478947368421053, 25, 50, seed=0) >> cache/test_methods-10--5--0.8478947368421053--25--50--seed-0.pkl
# gen_example(10, 5, 0.8478947368421053, 25, 50, f=None, seed=0) >> cache/gen_example-10--5--0.8478947368421053--25--50--f-None--seed-0.pkl
# test_baseline(10, 5, 0.8478947368421053, 25, 50, seed=1) >> cache/test_baseline-10--5--0.8478947368421053--25--50--seed-1.pkl
# gen_example(10, 5, 0.8478947368421053, 26, 50, f=None, jumble=None, seed=1) >> cache/gen_example-10--5--0.8478947368421053--26--50--f-None--jumble-None--seed-1.pkl
# test_methods(10, 5, 0.8478947368421053, 25, 50, seed=1) >> cache/test_methods-10--5--0.8478947368421053--25--50--seed-1.pkl
# gen_example(10, 5, 0.8478947368421053, 25, 50, f=None, seed=1) >> cache/gen_example-10--5--0.8478947368421053--25--50--f-None--seed-1.pkl
# KeyboardInterrupt

# %% [markdown]
# ## Varying Transition Counts

# %%
setup_end2end_tlen = {
    'n': [10],
    'L': [5],
    'tau': [0.1],
    't_len': np.linspace(100, 500, 19, dtype=int),
    'seed': range(5),
}

plot_end2end_tlen(setup_end2end_tlen, n_observations=2500)


setup_end2end_tlen = {
    'n': [10],
    'L': [5],
    'tau': [0.1],
    't_len': np.linspace(100, 5000, 19, dtype=int),
    'seed': range(5),
}

plot_end2end_tlen(setup_end2end_tlen, n_observations=25000)

# %% [markdown]
# ## Varying the Number of Trails

# %%
setup_end2end_n_samples = {
    'n': [10],
    'L': [2],
    'tau': [0.1],
    't_len': [100],
    'n_samples': np.linspace(100, 1000, 19, dtype=int),
    'seed': range(5),
}

plot_end2end_n_samples(setup_end2end_n_samples)


setup_end2end_n_samples = {
    'n': [10],
    'L': [2],
    'tau': [0.1],
    't_len': [500],
    'n_samples': np.linspace(10, 100, 19, dtype=int),
    'seed': range(5),
}

plot_end2end_n_samples(setup_end2end_n_samples)

# %% [markdown]
# ## Clustering Error

# %%
setup_test_clustering_methods = {
    'n': [10],
    'L': [5],
    'tau': [0.1],
    't_len': np.hstack((3, np.linspace(100, 2000, 20, dtype=int))),
    'n_samples': [100],
    'seed': range(10),
}

test_clustering_methods_plot(setup_test_clustering_methods)

# %% [markdown]
# # Experiments on the Last.fm Dataset

# %% [markdown]
# ## Training one Chain per User

# %%
plot_lastfm({
    'n': [10],
    'L': [2, 5, 8, 11, 14, 17, 20],
    'tau': [10],
    't_len': [10],
    'seed': range(5),
})


plot_lastfm_entropy({
    'n': [10],
    'L': [2, 5, 8, 11, 14, 17, 20],
    'tau': [10],
    't_len': [10],
    'seed': range(5),
})

# %% [markdown]
# ## Training one Chain for Multiple Users

# %%
plot_eval_lastfm({
    'n': [10],
    'L': np.arange(2, 10),
    'users': [10],
    'tau': [10],
    't_len': [10],
    'seed': range(5),
})
